# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ rse-units-moracz
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# Collecting rse-units-moracz
#   Downloading https://test-files.pythonhosted.org/packages/7c/b3/a97f246091d2e5dfbde4dddba037617e07bb111246ffd65308fa5e125d84/rse_units_moracz-0.1.0-py3-none-any.whl.metadata (708 bytes)
# Collecting pint>=0.24 (from rse-units-moracz)
#   Downloading pint-0.25.3-py3-none-any.whl.metadata (10 kB)
# Collecting flexcache>=0.3 (from pint>=0.24->rse-units-moracz)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.24->rse-units-moracz)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.24->rse-units-moracz) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.24->rse-units-moracz) (4.15.0)
# Downloading https://test-files.pythonhosted.org/packages/7c/b3/a97f246091d2e5dfbde4dddba037617e07bb111246ffd65308fa5e125d84/rse_units_moracz-0.1.0-py3-none-any.whl (2.9 kB)
# Downloading pint-0.25.3-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 5.4 MB/s eta 0:00:00
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Installing collected packages: flexparser, flexcache, pint, rse-units-moracz
# Successfully installed flexcache-0.3 flexparser-0.4 pint-0.25.3 rse-units-moracz-0.1.0

# %%
from rse_units_moracz import air_density, ureg

rho = air_density(300 * ureg.kelvin, 1000 * ureg.hectopascal)
print(f"{rho:.3~P}")
# Out:
# 1.16 kg/m³
